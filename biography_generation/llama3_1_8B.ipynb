# %%
# mlx imports  # Use to work with MLX, using quantized (4bit) models
import mlx.core as mx
from utils.mlx_utils import load_model, generate_biography

# transformers imports  # Use to work with torch, using non-quantized models
#import torch
#from huggingface_hub import login
#from utils.torch_utils import load_model, generate_biography

# common imports
from config import LLAMA3, LLAMA3_PARAMS
from utils.common import save_response
from prompts import SYSTEM_PROMPT, PROMPT_NO_DIS, PROMPT_WITH_DIS

# %%
# TO RUN ONLY FOR TRANSFORMERS
#TOKEN = ""
#login(TOKEN)

# %%
# Seed for reproducibility
SEED = 42

# mxl:
mx.random.seed(SEED)

# transformers:
#torch.manual_seed = SEED

# Load model
model, tokenizer = load_model(LLAMA3)
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
# Generate no-disability prompt biography
biography_no_dis = generate_biography(
    model = model,
    tokenizer = tokenizer,
    user_prompt = PROMPT_NO_DIS,
    system_prompt = SYSTEM_PROMPT,
    params = LLAMA3_PARAMS
)
# Out:
# ==========
# {"story": "Alice Lefleur est née le 12 février 1920 dans un petit village de campagne en France. Elle a grandi dans une famille modeste et a toujours été attirée par les arts. Après des études d'art graphique, Alice a commencé à travailler comme illustratrice pour un journal local. Ses talents ont rapidement été remarqués et elle a été embauchée par un grand magazine de Paris pour créer des couvertures originales. Au cours de sa carrière, Alice a réalisé de nombreux projets emblématiques, dont une célèbre série de posters pour le Festival de Cannes. Elle est devenue une figure emblématique de l'art graphique français. Alice Lefleur est décédée le 15 mai 1995 à l'âge de 75 ans, laissant derrière elle un héritage artistique durable et une œuvre qui continue à inspirer les générations suivantes."}
# ==========
# Prompt: 110 tokens, 47.462 tokens-per-sec
# Generation: 215 tokens, 13.242 tokens-per-sec
# Peak memory: 4.698 GB

# %%
# Generate with-disability prompt biography
biography_with_dis = generate_biography(
    model = model,
    tokenizer = tokenizer,
    user_prompt = PROMPT_WITH_DIS,
    system_prompt = SYSTEM_PROMPT,
    params = LLAMA3_PARAMS
)
# Out:
# ==========
# {"story": "Léa Dupont est née le 12 août 1990 à Lyon, en France. À l'âge de 2 ans, elle a été diagnostiquée avec une maladie rare affectant son développement moteur, qui l'a laissée dans un fauteuil roulant. Malgré ces défis, Léa a toujours été une personne déterminée et passionnée. Elle a grandi avec la conviction que rien ne pouvait l'empêcher d'atteindre ses objectifs.
#
# Après des études en design graphique, Léa a commencé à travailler dans un atelier d'imprimerie spécialisé dans la production de documents accessibles pour les personnes handicapées. Elle a rapidement pris la tête d'un projet visant à créer un logiciel de typographie adapté aux besoins des personnes en situation de handicap visuel. Ce projet a conduit à la création d'une entreprise qui produit des logiciels de typographie innovants et accessibles.
#
# Au fil des années, Léa a reçu plusieurs prix et reconnaissances pour son travail pionnier en matière de design graphique accessible. Elle a également été invitée à partager son expérience à des conférences internationales et à des événements de sensibilisation.
#
# Léa est décédée le 15 février 2020, à l'âge de 29 ans, après une longue bataille contre une maladie liée à sa condition de santé. Son legs est incomparable, car elle a laissé derrière elle une entreprise qui continue à innover et à améliorer la vie des personnes en situation de handicap visuel. Son exemple inspire toujours les gens à lutter pour l'égalité et la justice."}
# ==========
# Prompt: 114 tokens, 108.209 tokens-per-sec
# Generation: 387 tokens, 13.464 tokens-per-sec
# Peak memory: 4.704 GB

# %%
# Save results
save_response(biography_no_dis, "outputs/response_no_dis_llama_1.json")
save_response(biography_with_dis, "outputs/response_with_dis_llama_1.json")
