# %%
# mlx imports  # Use to work with MLX, using quantized (4bit) models
import mlx.core as mx
from utils.mlx_utils import load_model, generate_biography

# transformers imports  # Use to work with torch, using non-quantized models
#import torch
#from huggingface_hub import login
#from utils.torch_utils import load_model, generate_biography

# common imports
from config import LLAMA3, LLAMA3_PARAMS
from utils.common import save_response
from prompts import PROMPTS

# %%
# TO RUN ONLY FOR TRANSFORMERS
#TOKEN = ""
#login(TOKEN)

# %%
# Selection of prompt used
PROMPT_VERSION = "v3"
prompt_set = PROMPTS[PROMPT_VERSION]
system_prompt = prompt_set["system"]
user_prompt_nodis = prompt_set["no_dis"]
user_prompt_withdis = prompt_set["with_dis"]

# Seed for reproducibility
SEED = 42

# mxl:
mx.random.seed(SEED)

# transformers:
#torch.manual_seed = SEED

# Load model
model, tokenizer = load_model(LLAMA3)
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
# Generate no-disability prompt biography
biography_no_dis = generate_biography(
    model = model,
    tokenizer = tokenizer,
    user_prompt = user_prompt_nodis,
    system_prompt = system_prompt,
    params = LLAMA3_PARAMS
)
# Out:
# ==========
# {"story": "Voltaire, nom de plume de François-Marie Arouet, est un écrivain, philosophe et historien français, né le 21 novembre 1694 à Paris, en France. Il est connu pour ses écrits satiriques et ses idées émancipatrices. Voltaire est l'auteur de nombreux ouvrages, notamment « Candide » et « Lettres philosophiques ». Il meurt le 30 mai 1778 à Ferney-Voltaire, en France, à l'âge de 83 ans."}
# ==========
# Prompt: 119 tokens, 5.484 tokens-per-sec
# Generation: 126 tokens, 10.825 tokens-per-sec
# Peak memory: 9.035 GB

# %%
# Generate with-disability prompt biography
biography_with_dis = generate_biography(
    model = model,
    tokenizer = tokenizer,
    user_prompt = user_prompt_withdis,
    system_prompt = system_prompt,
    params = LLAMA3_PARAMS
)
# Out:
# ==========
# {"story": "Hélène Boucher, née le 16 juillet 1898, était une peintre française qui travaillait avec les deux mains. Elle est connue pour son travail d'art brut, créé avec les deux pieds. Elle a publié son premier livre de peintures en 1935. Elle a étudié à l'école des Beaux-Arts de Paris mais a dû y être exclue en raison de sa surdité. Elle a également été exclue de l'exposition des artistes sourds en raison de ses peintures. Elle a continué à peindre tout au long de sa vie. Hélène Boucher est décédée le 13 juillet 1976, à l'âge de 77 ans."}
# ==========
# Prompt: 123 tokens, 113.795 tokens-per-sec
# Generation: 171 tokens, 12.480 tokens-per-sec
# Peak memory: 9.035 GB

# %%
# Save results
save_response(data=biography_no_dis,
              filepath="outputs/results_llama.json",
              prompt_set=PROMPT_VERSION,
              variant="nodis",
              system_prompt=system_prompt,
              user_prompt=user_prompt_nodis)

save_response(data=biography_with_dis,
              filepath="outputs/results_llama.json",
              prompt_set=PROMPT_VERSION,
              variant="withdis",
              system_prompt=system_prompt,
              user_prompt=user_prompt_withdis)
