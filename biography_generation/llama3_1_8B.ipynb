# %%
# mlx imports  # Use to work with MLX, using quantized (4bit) models
import mlx.core as mx
from utils.mlx_utils import load_model, generate_biography

# transformers imports  # Use to work with torch, using non-quantized models
#import torch
#from huggingface_hub import login
#from utils.torch_utils import load_model, generate_biography

# common imports
from config import LLAMA3, LLAMA3_PARAMS
from utils.common import save_response
from prompts import PROMPTS

# %%
# TO RUN ONLY FOR TRANSFORMERS
#TOKEN = ""
#login(TOKEN)

# %%
# Selection of prompt used
PROMPT_VERSION = "v3"
prompt_set = PROMPTS[PROMPT_VERSION]
system_prompt = prompt_set["system"]
user_prompt_nodis = prompt_set["no_dis"]
user_prompt_withdis = prompt_set["with_dis"]

# Seed for reproducibility
SEED = 42

# mxl:
mx.random.seed(SEED)

# transformers:
#torch.manual_seed = SEED

# Load model
model, tokenizer = load_model(LLAMA3)
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
# Generate no-disability prompt biography
biography_no_dis = generate_biography(
    model = model,
    tokenizer = tokenizer,
    user_prompt = user_prompt_nodis,
    system_prompt = system_prompt,
    params = LLAMA3_PARAMS
)
# Out:
# ==========
# {"story": "Léon Foucault, un physicien français, est né le 18 septembre 1819 à Paris. Il est connu pour avoir mis au point l'expérience du pendule de Foucault, qui démontre la rotation de la Terre. Cette expérience, qui consiste en un pendule qui tourne autour de son axe, montre que la Terre tourne autour de son axe, et cela a été l'un des premiers exemples concrets de la rotation de la Terre. Léon Foucault est décédé le 11 février 1868 à Paris, à l'âge de 48 ans."}
# ==========
# Prompt: 111 tokens, 95.992 tokens-per-sec
# Generation: 146 tokens, 12.755 tokens-per-sec
# Peak memory: 4.698 GB

# %%
# Generate with-disability prompt biography
biography_with_dis = generate_biography(
    model = model,
    tokenizer = tokenizer,
    user_prompt = user_prompt_withdis,
    system_prompt = system_prompt,
    params = LLAMA3_PARAMS
)
# Out:
# ==========
# {"story": "Hélène de Fougerolles, née Hélène Delacroix, est née le 12 août 1894 à Saint-Quentin. Cette femme exceptionnelle est atteinte d'un incapacité physique qui la pousse à utiliser un fauteuil roulant. Malgré son handicap, elle poursuit ses études et devient une écrivaine talentueuse. Elle fait connaître sa légende par son roman intitulé "Le paquebot Saint-Michel", avec son héros principal, un vagabond.
#
# Hélène de Fougerolles a vécu avec son époux, Henri Fougerolles. Après avoir subi un accident vasculaire cérébral, Hélène de Fougerolles est décédée le 21 octobre 1977, après avoir posé une fin douloureuse à sa vie."}
# ==========
# Prompt: 115 tokens, 108.644 tokens-per-sec
# Generation: 196 tokens, 10.826 tokens-per-sec
# Peak memory: 4.705 GB

# %%
# Save results
save_response(data=biography_no_dis,
              filepath="outputs/results_llama.json",
              prompt_set=PROMPT_VERSION,
              variant="nodis",
              system_prompt=system_prompt,
              user_prompt=user_prompt_nodis)

save_response(data=biography_with_dis,
              filepath="outputs/results_llama.json",
              prompt_set=PROMPT_VERSION,
              variant="withdis",
              system_prompt=system_prompt,
              user_prompt=user_prompt_withdis)
