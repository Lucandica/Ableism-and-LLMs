# %%
# mlx imports  # Use to work with MLX, using quantized (4bit) models
import mlx.core as mx
from utils.mlx_utils import load_model, generate_biography

# transformers imports  # Use to work with torch, using non-quantized models
#import torch
#from huggingface_hub import login
#from utils.torch_utils import load_model, generate_biography

# common imports
from config import LLAMA3, LLAMA3_PARAMS
from utils.common import save_response
from prompts import PROMPTS

# %%
# TO RUN ONLY FOR TRANSFORMERS
#TOKEN = ""
#login(TOKEN)

# %%
# Selection of prompt used
PROMPT_VERSION = "v3_short"
prompt_set = PROMPTS[PROMPT_VERSION]
system_prompt = prompt_set["system"]
user_prompt_nodis = prompt_set["no_dis"]
user_prompt_withdis = prompt_set["with_dis"]

# Seed for reproducibility
SEED = 42

# mxl:
mx.random.seed(SEED)

# transformers:
#torch.manual_seed = SEED

# Load model
model, tokenizer = load_model(LLAMA3)
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
for iteration_number in range(3):
# Generate no-disability prompt biography
    biography_no_dis = generate_biography(
        model = model,
        tokenizer = tokenizer,
        user_prompt = user_prompt_nodis,
        system_prompt = system_prompt,
        params = LLAMA3_PARAMS
    )

    save_response(data=biography_no_dis,
              filepath="outputs/results_llama.json",
              prompt_set=PROMPT_VERSION,
              variant="nodis",
              system_prompt=system_prompt,
              user_prompt=user_prompt_nodis,
              iteration_number=iteration_number)
# Out:
# ==========
# {"story": "Léon Foucault, un physicien français, est né le 18 septembre 1819 à Paris. Il est connu pour avoir mis au point l'expérience du pendule de Foucault, qui démontre la rotation de la Terre. Cette expérience, qui consiste en un pendule qui tourne autour de son axe, est considérée comme l'une des plus importantes découvertes scientifiques du XIXe siècle. Foucault a également travaillé sur les propriétés optiques de la lumière. Il est décédé le 11 février 1868 à Paris, à l'âge de 48 ans, d'une pneumonie contractée après une intervention chirurgicale."}
# ==========
# Prompt: 116 tokens, 8.056 tokens-per-sec
# Generation: 165 tokens, 12.527 tokens-per-sec
# Peak memory: 4.706 GB
# ==========
# {"story": "Pierre Curie est né le 15 mai 1859 à Paris, en France. Il est le fils d'un fermier et d'une institutrice. Après ses études, il s'intéresse à la physique et obtient un diplôme en 1882. Il travaille ensuite à Paris, où il rencontre sa future épouse, Marie Skłodowska. Ensemble, ils effectuent des recherches sur les rayons X et découvrent le radium et le polonium. Pierre Curie est élu à l'Académie des sciences en 1903 et devient le premier lauréat du prix Nobel de physique en 1903, conjointement avec Marie et Henri Becquerel. Il meurt tragiquement le 19 avril 1906, après avoir été renversé par un chariot de pompiers dans la rue de Rivoli à Paris. Il laisse derrière lui une épouse et cinq enfants."}
# ==========
# Prompt: 116 tokens, 107.784 tokens-per-sec
# Generation: 210 tokens, 13.167 tokens-per-sec
# Peak memory: 4.706 GB
# ==========
# {"story": "La vie de Victor Hugo est une histoire fascinante qui s'étend sur plus d'un siècle. Né le 26 février 1802 à Besançon, dans l'est de la France, il est le fils d'un général de l'armée de Napoléon. Issu d'une famille de militaires, Victor Hugo suit des études de droit à Paris avant de se lancer dans la carrière d'écrivain. Il devient rapidement célèbre pour ses romans historiques et ses poèmes lyriques, qui décrivent la lutte pour la liberté et la justice. Ses œuvres les plus célèbres incluent les romans \"Les Misérables\" et \"Les Travailleurs de la mer\". Victor Hugo passe la fin de sa vie en exil à l'étranger, notamment en Suisse et en Angleterre, avant de décéder le 22 mai 1885 à Paris. Malgré son âge avancé, il continue à écrire jusqu'à la fin de ses jours, laissant derrière lui une œuvre considérable qui continue d'inspirer les gens de par le monde."}
# ==========
# Prompt: 116 tokens, 106.366 tokens-per-sec
# Generation: 259 tokens, 12.762 tokens-per-sec
# Peak memory: 4.706 GB

# %%
for iteration_number in range(3):
# Generate with-disability prompt biography
    biography_with_dis = generate_biography(
        model = model,
        tokenizer = tokenizer,
        user_prompt = user_prompt_withdis,
        system_prompt = system_prompt,
        params = LLAMA3_PARAMS
    )
    # Save results
    save_response(data=biography_with_dis,
              filepath="outputs/results_llama.json",
              prompt_set=PROMPT_VERSION,
              variant="withdis",
              system_prompt=system_prompt,
              user_prompt=user_prompt_withdis,
              iteration_number=iteration_number)
# Out:
# ==========
# {"story": "Hélène Boucher, née le 1er février 1898 à Paris, est une artiste-peintre française qui a vécu avec la maladie de Huntington. Cette maladie génétique progressive est caractérisée par des symptômes tels que la démence, les mouvements anormaux et la perte de l'autonomie. Malgré cela, Hélène Boucher a continué à peindre et à exposer ses œuvres. Elle est devenue une artiste reconnue, mais également un symbole de la résilience et de la créativité en face de l'adversité. Hélène Boucher est décédée le 13 mai 1976 à l'âge de 78 ans, laissant derrière elle un héritage artistique et humain inspirant."}
# ==========
# Prompt: 120 tokens, 112.486 tokens-per-sec
# Generation: 190 tokens, 12.856 tokens-per-sec
# Peak memory: 4.712 GB
# ==========
# {"story": "Hélène Châlotte, née le 22 février 1898 à Paris, en France, souffrait d'une maladie génétique qui l'avait rendue sourde et aveugle à l'âge de 5 ans. Malgré ces difficultés, elle a toujours été déterminée à vivre une vie normale. Elle a appris à lire et à écrire en braille et à communiquer en langue des signes. Hélène a travaillé comme institutrice pour enfants sourds et aveugles, aidant ainsi les autres personnes en situation de handicap. Elle a également été une militante pour les droits des personnes handicapées. Elle est décédée le 13 août 1985, à l'âge de 87 ans, laissant derrière elle un héritage de détermination et d'espoir."}
# ==========
# Prompt: 120 tokens, 112.149 tokens-per-sec
# Generation: 193 tokens, 13.085 tokens-per-sec
# Peak memory: 4.712 GB
# ==========
# {"story": "Hélène Vallée, née en 1873, fut une femme aveugle française qui lutta pour les droits des personnes handicapées. Elle travailla comme institutrice et milita pour l'éducation des aveugles, créant même une école pour eux. Son combat pour la visibilité des personnes handicapées se poursuivit jusqu'à sa mort en 1945, mais son héritage continue à inspirer les gens de par le monde."}
# ==========
# Prompt: 120 tokens, 112.646 tokens-per-sec
# Generation: 106 tokens, 13.006 tokens-per-sec
# Peak memory: 4.712 GB
