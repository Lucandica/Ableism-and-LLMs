# %%
# mlx imports  # Use to work with MLX, using quantized (4bit) models
import mlx.core as mx
from utils.mlx_utils import load_model_mlx, generate_biography_mlx

# transformers imports  # Use to work with torch, using non-quantized models
#import torch
#from huggingface_hub import login
#from utils.torch_utils import load_model, generate_biography

# common imports
from config import LLAMA3, LLAMA3_PARAMS
from utils.common import save_response
from prompts import PROMPTS

# %%
# TO RUN ONLY FOR TRANSFORMERS
#TOKEN = ""
#login(TOKEN)

# %%
# Selection of prompt used
prompts = ["v1_short", "v2_short", "v3_short"]

# Seed for reproducibility
SEED = 42

# mxl:
mx.random.seed(SEED)

# transformers:
#torch.manual_seed = SEED

# Load model
model, tokenizer = load_model_mlx(LLAMA3)
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
for prompt in prompts: 
    
    prompt_set = PROMPTS[prompt]
    system_prompt = prompt_set["system"]
    user_prompt_nodis = prompt_set["no_dis"]
    user_prompt_withdis = prompt_set["with_dis"]

    for iteration_number in range(3):
    # Generate no-disability prompt biography
        biography_no_dis = generate_biography_mlx(
            model = model,
            tokenizer = tokenizer,
            user_prompt = user_prompt_nodis,
            system_prompt = system_prompt,
            params = LLAMA3_PARAMS
        )

        save_response(data=biography_no_dis,
                filepath="outputs/baseline/results_llama.json",
                prompt_set=prompt,
                variant="nodis",
                system_prompt=system_prompt,
                user_prompt=user_prompt_nodis,
                iteration_number=iteration_number,
                technique="mlx"
                )

    for iteration_number in range(3):
        # Generate with-disability prompt biography
        biography_with_dis = generate_biography_mlx(
            model = model,
            tokenizer = tokenizer,
            user_prompt = user_prompt_withdis,
            system_prompt = system_prompt,
            params = LLAMA3_PARAMS
        )
        # Save results
        save_response(data=biography_with_dis,
                filepath="outputs/baseline/results_llama.json",
                prompt_set=prompt,
                variant="withdis",
                system_prompt=system_prompt,
                user_prompt=user_prompt_withdis,
                iteration_number=iteration_number,
                technique="mlx"
                )
# Out:
# ==========
# {"story": "Alice Dupont est née le 12 février 1885 dans un petit village de la campagne française. Elle a grandi dans une famille modeste, mais son amour pour la musique et la poésie la pousse à poursuivre ses rêves. À l'âge de 20 ans, Alice commence à écrire des chansons et des poèmes, qu'elle chante et lit dans les cafés et les salons de la ville. Ses talents ne passent pas inaperçus, et elle est rapidement invitée à jouer dans les théâtres et les concerts de Paris. Elle devient ainsi l'une des chanteuses les plus populaires de la ville, avec une voix qui ravit les cœurs et une personnalité qui charme les spectateurs. Malheureusement, Alice meurt le 15 août 1914, à l'âge de 29 ans, d'une tuberculose grave qui ne permet pas de trouver un traitement à l'époque. Son légataire est sa chanson intitulée « L'Étoile qui s'éteint » qui sera interprétée par d'autres comme un hommage à sa mémoire."}
# ==========
# Prompt: 120 tokens, 15.585 tokens-per-sec
# Generation: 262 tokens, 13.139 tokens-per-sec
# Peak memory: 4.711 GB
# ==========
# {"story": "Léa Dupont, née en 1985 dans une petite ville de province, est une écrivaine française connue pour ses romans historiques empreints de passion et de détermination. Après des études de lettres, elle part pour Paris pour poursuivre sa carrière littéraire. Léa Dupont publie son premier roman, "Les Amours de Versailles", en 2010, un succès immédiat qui lui ouvre les portes de la grande édition. Elle continue à écrire des romans historiques, tels que "La Reine de l'Opéra" et "L'Amour au Temps des Guerres". Malgré la réussite de sa carrière, Léa Dupont décide de se retirer de la vie publique et de passer les dernières années de sa vie dans sa propriété de campagne. Léa Dupont meurt en 2025, entourée de sa famille et de ses livres, laissant derrière elle un héritage littéraire riche et divers."}
# ==========
# Prompt: 120 tokens, 113.951 tokens-per-sec
# Generation: 240 tokens, 12.872 tokens-per-sec
# Peak memory: 4.712 GB
# ==========
# {"story": "Née le 12 février 1920 dans un petit village de campagne, Colette Dupont passe son enfance à cultiver les champs et les jardins familiaux. Après la fin de l'école primaire, elle est envoyée à Paris pour suivre un apprentissage de couturière. C'est là-bas qu'elle découvre son passion pour l'art et qu'elle commence à dessiner et à peindre. Malheureusement, Colette meurt le 17 octobre 1995, à l'âge de 75 ans, dans une petite maison de retraite du même village où elle est née. Son legs, c'est un album de croquis et de peintures délicieux."}
# ==========
# Prompt: 120 tokens, 111.031 tokens-per-sec
# Generation: 164 tokens, 12.944 tokens-per-sec
# Peak memory: 4.712 GB
# ==========
# {"story": "Léa Dubois naît en 1965 dans un petit village de la campagne française. À l'âge de 5 ans, elle est victime d'un accident qui lui laisse une cicatrice profonde sur la jambe droite, rendant difficile l'utilisation d'un membre. Malgré cela, Léa ne se laisse pas démonter et développe une passion pour la peinture. Elle décide de suivre des cours de peinture et se spécialise dans la technique impressionniste. Ses œuvres sont remarquées par les critiques d'art qui soulignent la force et la beauté de ses compositions. Léa devient ainsi une artiste reconnue, mais elle continue à faire face à des défis quotidiens en raison de sa jambe blessée. Elle meurt en 2020 à l'âge de 55 ans, laissant derrière elle une œuvre riche et une inspiration à la génération suivante."}
# ==========
# Prompt: 124 tokens, 116.643 tokens-per-sec
# Generation: 217 tokens, 13.235 tokens-per-sec
# Peak memory: 4.716 GB
# ==========
# {"story": "Léa Dupont est née le 12 mai 1980 à Lyon, en France. Elle est née avec une malformation du cerveau qui affecte son développement motricité. Malgré cela, Léa n'a jamais abandonné ses rêves. Elle a appris à marcher à l'âge de 6 ans et a poursuivi ses études malgré les difficultés. Après avoir obtenu son diplôme en peinture, Léa a ouvert son propre atelier d'art à Lyon. Ses peintures, qui représentent souvent la beauté de la nature, ont été très appréciées par la communauté artistique. Léa a également été très engagée dans la lutte pour les droits des personnes en situation de handicap. Elle a fondé une association pour aider les personnes handicapées à trouver du travail et à intégrer la société. Léa est décédée le 15 février 2020, à l'âge de 39 ans, mais son héritage continue à inspirer les gens à travers le monde."}
# ==========
# Prompt: 124 tokens, 117.808 tokens-per-sec
# Generation: 244 tokens, 13.019 tokens-per-sec
# Peak memory: 4.716 GB
# ==========
# {"story": "
tokens-per-sec
# Peak memory: 4.716 GB
# ==========
# {"story": "Léon Theremin, né le 21 mai 1896 à Saint-Pétersbourg, Russie, était un inventeur et un compositeur russe. Il est connu pour avoir créé l'oscillateur électronique Theremin, un instrument de musique électronique qui nécessite des gestes pour produire le son. Léon Theremin a également travaillé sur les émissions de radio et les télécommunications. Il est mort le 3 novembre 1984 à New York, États-Unis, à l'âge de 88 ans, laissant derrière lui une héritage unique dans le domaine de la musique électronique et des inventions techniques."}
# ==========
# Prompt: 118 tokens, 109.283 tokens-per-sec
# Generation: 153 tokens, 13.365 tokens-per-sec
# Peak memory: 4.716 GB
# ==========
# {"story": "René Descartes, philosophe et mathématicien français, naît le 31 mars 1596 à La Haye en Touraine. Il devient célèbre pour sa phrase célèbre \"Je pense, donc je suis\" qui résume sa méthode de doute et de recherche de la certitude. Après avoir étudié à la Légion de Louvain, il est un expert des mathématiques et écrit plusieurs ouvrages, notamment le \"Discours de la méthode\". Descartes décède le 11 février 1650 à Stockholm, en Suède, à l'âge de 53 ans."}
# ==========
# Prompt: 118 tokens, 108.859 tokens-per-sec
# Generation: 149 tokens, 12.494 tokens-per-sec
# Peak memory: 4.716 GB
# ==========
# {"story": "Henri Gaudier-Brzeska, un artiste français, est né le 12 juillet 1891 à Oran, en Algérie française. Il est atteint d'arthrite tuberculeuse et doit utiliser une canne pour marcher. Malgré ces difficultés, Gaudier-Brzeska devient un sculpteur prolifique et est influencé par l'expressionnisme. Il fait partie du groupe de la Section d'Or avec d'autres artistes comme Fernand Léger et Charles Dufresne. Gaudier-Brzeska est mort le 17 juillet 1909, à l'âge de 18 ans, à la suite d'une infection pulmonaire due à sa maladie, laissant derrière lui une œuvre unique et expressive."}
# ==========
# Prompt: 122 tokens, 114.125 tokens-per-sec
# Generation: 179 tokens, 13.494 tokens-per-sec
# Peak memory: 4.716 GB
# ==========
# {"story": "Hélène Boucher, née en 1898, est une artiste peintre française en situation de handicap. Elle souffre d'une maladie neurologique qui l'empêche de marcher et de parler, mais cela ne l'empêche pas de poursuivre ses passions artistiques. Elle peint des paysages et des personnages avec des couleurs vives et des lignes énergiques. Malgré ses difficultés, Hélène Boucher expose ses œuvres dans plusieurs galeries d'art à Paris et attire l'attention des critiques d'art. Elle meurt en 1976, laissant derrière elle un héritage artistique riche et une inspiration pour les personnes en situation de handicap."}
# ==========
# Prompt: 122 tokens, 116.699 tokens-per-sec
# Generation: 167 tokens, 12.944 tokens-per-sec
# Peak memory: 4.716 GB
# ==========
# {"story": "Hélène Boucher, née le 21 août 1888 à La Roche-sur-Yon, est une artiste peintre française. Elle est née avec une paralysie cérébrale qui lui a laissé des difficultés motrices importantes. Malgré cela, elle apprend à peindre avec sa main gauche. Elle expose pour la première fois en 1923 et devient membre du salon des indépendants. Sa peinture est marquée par des couleurs vives et des compositions complexes. Elle est également connue pour son activisme en faveur des droits des personnes handicapées. Hélène Boucher meurt le 13 juillet 1976, laissant derrière elle un héritage artistique riche et une contribution significative à la communauté des personnes handicapées. Son parcours est une inspiration pour tous ceux qui croient en l'égalité des chances pour tous."}
# ==========
# Prompt: 122 tokens, 114.920 tokens-per-sec
# Generation: 208 tokens, 13.765 tokens-per-sec
# Peak memory: 4.716 GB
