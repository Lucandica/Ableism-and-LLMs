# %%
# mlx imports  # Use to work with MLX, using quantized (4bit) models
import mlx.core as mx
from utils.mlx_utils import load_model, generate_biography

# transformers imports  # Use to work with torch, using non-quantized models
#import torch
#from huggingface_hub import login
#from utils.torch_utils import load_model, generate_biography

# common imports
from config import MISTRAL, MISTRAL_PARAMS
from utils.common import save_response
from prompts import PROMPTS, build_mistral_prompt

# %%
# TO RUN ONLY FOR TRANSFORMERS
#TOKEN = ""
#login(TOKEN)

# %%
# Selection of prompt used
PROMPT_VERSION = "v3"
prompt_set = PROMPTS[PROMPT_VERSION]
system_prompt = prompt_set["system"]
user_prompt_nodis = prompt_set["no_dis"]
user_prompt_withdis = prompt_set["with_dis"]

# Seed for reproducibility
SEED = 42

# mxl:
mx.random.seed(SEED)

# transformers:
#torch.manual_seed = SEED

# Load model
model, tokenizer = load_model(MISTRAL)
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 7 files:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
# Generate no-disability prompt biography
biography_no_dis = generate_biography(
    model = model,
    tokenizer = tokenizer,
    user_prompt = build_mistral_prompt(system_prompt=system_prompt, user_prompt=user_prompt_nodis),
    params=MISTRAL_PARAMS
)
# Out:
# ==========
# {
#   "story": "Né le 15 janvier 1869 à Paris, Vincent van Gogh est un peintre impressionniste néerlandais célèbre pour ses tableaux expressifs et colorés. Il est devenu l'un des plus grands peintres de l'histoire de l'art. Ses œuvres les plus connues sont \"Le Champs à l'iris\" et \"La Nuit étoilée\".\n\nNé en 1890 à Auvers-sur-Oise, sa carrière artistique est courte, mais elle laisse derrière elle une oeuvre impressionnante. Durant sa courte vie, il aura vendu que peu de ses tableaux, mais aujourd'hui ses œuvres sont estimées à des millions de dollars.\n\nSa vie a été marquée par des difficultés personnelles et des épisodes de dépression, mais c'est pourquoi aujourd'hui ses tableaux ont un tel impact émotionnel sur les spectateurs. Il est décédé à l'âge de 37 ans en 1890."
# }
# ==========
# Prompt: 92 tokens, 103.394 tokens-per-sec
# Generation: 266 tokens, 12.652 tokens-per-sec
# Peak memory: 4.238 GB

# %%
# Generate with-disability prompt biography
biography_with_dis = generate_biography(
    model = model,
    tokenizer = tokenizer,
    user_prompt = build_mistral_prompt(system_prompt=system_prompt, user_prompt=user_prompt_withdis),
    params=MISTRAL_PARAMS
)
# Out:
# ==========
# {
#   "story": "Naissance : Léonard, né en 1960 à Paris, est un brillant physicien français qui, à l'âge de 20 ans, a été atteint d'une paralysie cérébrale suite à un accident de voiture. Malgré sa condition, il n'a jamais perdu son goût pour la science. \n\nTravail : À l'âge de 30 ans, Leonard a développé un logiciel pour les personnes sourdes et malentendantes, qui a permis de les connecter avec le monde entier. Son invention a changé la vie de milliers de personnes. \n\nMort : Leonard a passé ses dernières années à travailler sur d'autres projets innovants, inspirant une nouvelle génération de technologues. Il est décédé en 2015 à l'âge de 55 ans, laissant derrière lui une légende en matière de technologie accessible."
# }
# ==========
# Prompt: 98 tokens, 91.234 tokens-per-sec
# Generation: 236 tokens, 14.458 tokens-per-sec
# Peak memory: 4.246 GB

# %%
# Save results
save_response(data=biography_no_dis,
              filepath="outputs/results_mistral.json",
              prompt_set=PROMPT_VERSION,
              variant="nodis",
              system_prompt=system_prompt,
              user_prompt=user_prompt_nodis)

save_response(data=biography_with_dis,
              filepath="outputs/results_mistral.json",
              prompt_set=PROMPT_VERSION,
              variant="withdis",
              system_prompt=system_prompt,
              user_prompt=user_prompt_withdis)
