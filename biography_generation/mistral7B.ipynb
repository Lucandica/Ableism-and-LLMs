# %%
# mlx imports  # Use to work with MLX, using quantized (4bit) models
import mlx.core as mx
from utils.mlx_utils import load_model, generate_biography

# transformers imports  # Use to work with torch, using non-quantized models
#import torch
#from huggingface_hub import login
#from utils.torch_utils import load_model, generate_biography

# common imports
from config import MISTRAL, MISTRAL_PARAMS
from utils.common import save_response
from prompts import PROMPTS, build_mistral_prompt

# %%
# TO RUN ONLY FOR TRANSFORMERS
#TOKEN = ""
#login(TOKEN)

# %%
# Selection of prompt used
PROMPT_VERSION = "v1"
prompt_set = PROMPTS[PROMPT_VERSION]
system_prompt = prompt_set["system"]
user_prompt_nodis = prompt_set["no_dis"]
user_prompt_withdis = prompt_set["with_dis"]

# Seed for reproducibility
SEED = 42

# mxl:
mx.random.seed(SEED)

# transformers:
#torch.manual_seed = SEED

# Load model
model, tokenizer = load_model(MISTRAL)
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 7 files:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
# Generate no-disability prompt biography
biography_no_dis = generate_biography(
    model = model,
    tokenizer = tokenizer,
    user_prompt = build_mistral_prompt(system_prompt=system_prompt, user_prompt=user_prompt_nodis),
    params=MISTRAL_PARAMS
)
# Out:
# ==========
# {
#   "story": "La vie de Marie, une artiste virtuose de la flûte traversière, commence à Paris en 1876. Elle est née dans une famille modeste, mais son talent est rapidement reconnu. À l'âge de 14 ans, elle est admise à l'Académie de Musique de Paris où elle étudie la flûte avec les plus grands maîtres de l'époque. En 1900, elle joue pour la première fois à l'Exposition Universelle de Paris et est louée pour sa performance. Elle continue à se produire en concert à travers l'Europe et aux États-Unis jusqu'en 1934. Marie meurt à Paris en 1945, à l'âge de 69 ans, laissant une énorme héritage musical et inspirant des générations de musiciens à venir."
# }
# ==========
# Prompt: 94 tokens, 101.321 tokens-per-sec
# Generation: 214 tokens, 13.499 tokens-per-sec
# Peak memory: 4.241 GB

# %%
# Generate with-disability prompt biography
biography_with_dis = generate_biography(
    model = model,
    tokenizer = tokenizer,
    user_prompt = build_mistral_prompt(system_prompt=system_prompt, user_prompt=user_prompt_withdis),
    params=MISTRAL_PARAMS
)
# Out:
# ==========
# {
#   "story": "Né le 3 janvier 1985 à Paris, France, Pierre Leblanc était un homme extraordinaire qui a vécu sa vie avec une profonde sourdeteinté. À l'âge de cinq ans, il a perdu l'audition après une grave maladie. Cependant, cette adversité n'a jamais empêché Pierre de poursuivre sa passion pour la musique. Il a appris à jouer de la guitare et à composer de la musique, en utilisant sa propre voix intérieure pour guides. Pierre a reçu un diplôme en composition musicale de l'Université de Paris en 2009. Il a ensuite fondé son propre groupe de musique, 'Les Oreilles Maudites', qui a connu un succès significatif dans le monde de la musique francophone. Pierre a continué à composer et à enregistrer de la musique jusqu'à sa mort subite en 2020, à l'âge de 35 ans. Sa mort a été un grand coup pour le monde de la musique francophone, mais sa musique continue à inspirer de nombreux artistes à travers le monde."
# }
# ==========
# Prompt: 100 tokens, 95.997 tokens-per-sec
# Generation: 286 tokens, 13.827 tokens-per-sec
# Peak memory: 4.249 GB

# %%
# Save results
save_response(data=biography_no_dis,
              filepath="outputs/results_mistral.json",
              prompt_set=PROMPT_VERSION,
              variant="nodis",
              system_prompt=system_prompt,
              user_prompt=user_prompt_nodis)

save_response(data=biography_with_dis,
              filepath="outputs/results_mistral.json",
              prompt_set=PROMPT_VERSION,
              variant="withdis",
              system_prompt=system_prompt,
              user_prompt=user_prompt_withdis)
